# %%
# %load_ext autoreload
# %autoreload 2
from main import set_loggers_level
set_loggers_level()
from matplotlib import pyplot as plt

# This is a bit of magic to make matplotlib figures appear inline in the
# notebook rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'# Keep this line first.
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.DataUtils import skin_cancer_detector_parse_dataset_full_quality
from src.DataProvider import DataProvider

images, metadata_df = skin_cancer_detector_parse_dataset_full_quality("archive", 100)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 252.53it/s]

# %%
images

plt.title('Test Image')
plt.imshow(images[0])
plt.show()
